# %%
# Рисовать графики сразу же
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('ggplot')  # Красивые графики
plt.rcParams['figure.figsize'] = (15, 5)  # Размер картинок

# %%
fixed_df = pd.read_csv(r'C:\Users\demon2513\Documents\titanic.csv',  # Это то, куда вы скачали файл
                       sep=',', encoding='latin1', dayfirst=True)
fixed_df[:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
m,f = 0,0

for i in fixed_df['Sex']:
    if i == 'male':
        m = m + 1
    else:
        f = f + 1
        
    
print('m={} f={}  SUM={}'.format(m, f, m + f))
# Out:
# m=577 f=314  SUM=891

# %%
# fixed_df['Age'].plot()

comp = fixed_df['Cabin'].value_counts()
comp.plot(kind='bar')

# %%
comp.index.
